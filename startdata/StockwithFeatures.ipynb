# %%
import pandas as pd

# %%
df = pd.read_csv("stocks.csv")
df
# Out:
#            date ticker     date.1     open     high      low    close  \
# 0     3/27/2018  GOOGL  3/27/2018  1063.90  1064.54   997.62  1006.94
# 1     3/26/2018  GOOGL  3/26/2018  1050.60  1059.27  1010.58  1054.09
# 2     3/23/2018  GOOGL  3/23/2018  1051.37  1066.78  1024.87  1026.55
# 3     3/22/2018  GOOGL  3/22/2018  1080.01  1083.92  1049.64  1053.15
# 4     3/21/2018  GOOGL  3/21/2018  1092.57  1108.70  1087.21  1094.00
# ...         ...    ...        ...      ...      ...      ...      ...
# 6206   1/8/2010   AAPL   1/8/2010   210.30   212.00   209.06   211.98
# 6207   1/7/2010   AAPL   1/7/2010   211.75   212.00   209.05   210.58
# 6208   1/6/2010   AAPL   1/6/2010   214.38   215.23   210.75   210.97
# 6209   1/5/2010   AAPL   1/5/2010   214.60   215.59   213.25   214.38
# 6210   1/4/2010   AAPL   1/4/2010   213.43   214.50   212.38   214.01
#
#         volume  ex-dividend  split_ratio     adj_open     adj_high  \
# ...
